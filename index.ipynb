# %% [markdown]
# ## Import Libraries

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Test for Response Status

# %%
url = 'https://www.jumia.com.ng/'
r = requests.get(url)
print(r.status_code)
# Out:
# 200

# %%
# https://www.neostore.ng/
url = 'https://www.neostore.ng/'
r = requests.get(url)
print(r.status_code)
# Out:
# 200
